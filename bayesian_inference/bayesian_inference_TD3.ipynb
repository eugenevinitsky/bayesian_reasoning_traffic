# %%
"""Use Nick's TD3 trained policy to perform inference on whether there is a pedestrian or not"""

import argparse
from datetime import datetime
import gym
import os
import sys
import time
import matplotlib.pyplot as plt
import numpy as np
import PyQt5

import ray
try:
    from ray.rllib.agents.agent import get_agent_class
except ImportError:
    from ray.rllib.agents.registry import get_agent_class
from ray.tune.registry import register_env

from flow.algorithms.maddpg.maddpg import DEFAULT_CONFIG as MADDPG_DEFAULT_CONFIG, MADDPGTrainer


from flow.core.util import emission_to_csv
from flow.utils.registry import make_create_env
from flow.utils.rllib import get_flow_params
from flow.utils.rllib import get_rllib_config
from flow.utils.rllib import get_rllib_pkl

from examples.rllib.multiagent_exps.test_predictor.pedestrian_policy_1 import create_env, create_agent
from examples.rllib.multiagent_exps.bayesian_0_env import make_flow_params as bayesian_0_flow_params

EXAMPLE_USAGE = """
example usage:
    python ./visualizer_rllib.py /ray_results/experiment_dir/result_dir 1
Here the arguments are:
1 - the path to the simulation results
2 - the number of the checkpoint
"""

# %%
import tensorflow as tf
import tensorflow_probability as tfp
import ray
import gym

# %%
tfp.__version__
gym.__version__
# Out:
# '0.14.0'

# %% [markdown]
# Policy takes in an observation of length 22 (10 + max_num_objects * 3)
#
# observation[4:10] = ped_param
#
# I want the set to posterior probabilities: $$Pr(\text{ped_in_grid_i} | action), \forall i = 1, \ldots, 6$$
#
# $Pr(\text{ped_in_grid_i} | \text{action}) = \frac{Pr(\text{action} | \text{ped_in_i}) Pr(\text{ped_in_i})}{Pr(\text{action})}$
#
# $\Pr(action) = \sum_{i=1}^6 \Pr(action | ped\text{_}in\text{_}i) \Pr(ped\text{_}in\text{_}i)$
#
#
# Compute Pr(action | ped_in_i) by taking
#
# 1. actual state e.g. s = [a, b, c, d, [0], e, _, _, _], where I only care about the ith grid (suppose there is no ped in the ith grid)
#
# 2. actual state with flipped pedestrian at grid i, i.e
# s_flipped = [a, b, c, d, [1], e, _, _, _]
#
# Input these two into the policy to get PDFs:
#
# If $s[i] == 0,$ ped_PDF = $\pi(s\text{_}flipped)$ and no_ped_PDF = $\pi(s)$. Pr(action | ped_in_i) = $\frac{ped\text{_}PDF}{ped\text{_}PDF + ped\text{_}no\text{_}PDF}$
#
# If $s[i] == 1,$ ped_PDF = $\pi(s)$ and no_ped_PDF = $\pi(s\text{_}flipped)$. Pr(action | ped_in_i) = $\frac{ped\text{_}PDF}{ped\text{_}PDF + ped\text{_}no\text{_}PDF}$
#
# and do the usual normalization thing to get Pr(action | ped_in_i)

# %% [markdown]
# # The Math
#
# Now, suppose we have access to some PDF $f(a| o_1, o_2, \ldots, o_6)$, where $o_i$ for $i = 1, \ldots, 6$ are indicator variables for whether a pedestrian is or isn't on grid $i$ (as defined in the figure $<insert figure>)$.
#
# Our goal: $p(o_i = b_i| a), \forall i = 1, \ldots, 6$, $b_i \in \{0, 1\}$. We get these 'single' conditional probabilities we want by marginalizing:
#
# \begin{equation}
#     p(o_1 = b_1 | a) = \sum_{b_2, \ldots, b_6} p(o_1 = b_1, \ldots, o_6 = b_6 |a )
# \end{equation}
#
# Thus, to get these 'single' conditional probabilities, we need to calculate these joint conditional probabilities: $p(o_1 = b_1, \ldots, o_6 = b_6 |a), \forall b_i \in \{0, 1\}, i \in 1, \ldots, 6$. Via Bayes' rule again:
#
# \begin{equation}
#     p(o_1 = b_1, \ldots, o_6 = b_6 |a ) = \frac{p(a | o_1 = b_1, \ldots, o_6 = b_6) p(o_1, \ldots, o_6)}{p(a)}
# \end{equation}
#
# Since we only have access to the PDF $f(a | o_1 = b_1, \ldots, o_6 = b_6)$, we'd end up with the PDF $f(o_1 = b_1, \ldots, o_6 = b_6 |a )$ from the equation above. That is, we get:
#
# \begin{equation}
#     f(o_1 = b_1, \ldots, o_6 = b_6 |a ) = \frac{f(a | o_1 = b_1, \ldots, o_6 = b_6) p(o_1, \ldots, o_6)}{p(a)}
# \end{equation}
#
# To get the probability $p(o_1 = b_1, \ldots, o_6 = b_6 |a)$, we normalize:
#
# \begin{equation}
# p(o_1 = b_1, \ldots, o_6 = b_6 |a) = \frac{f(o_1 = b_1, \ldots, o_6 = b_6 |a)}{c}
# \end{equation}
#
# where $c = \sum_{b_1, \ldots, b_6} f(o_1 = b_1, \ldots, o_6 = b_6 |a)$
#
# Note that we can drop the denominator $p(a)$ in equation 6 since we're normalizing these PDFs into probabilities. Thus, we can just let
#
# \begin{equation}
# f(o_1 = b_1, \ldots, o_6 = b_6 |a) = f(a | o_1 = b_1, \ldots, o_6 = b_6) p(o_1 = b_1, \ldots, o_b = b_6)
# \end{equation}
#
# Notice that we'll need $2^6$ of these conditional densities / probabilities.
# Explicitly, we need $2^6$ of $f(a | \cap_i o_i = b_i), f(\cap_i o_i = b_i | a), p(\cap_i o_i = b_i | a)$.

# %%
def run_env(env, agent, config, flow_params):
    """Run the simulation and control the rl car using the trained policy. 
    
    observation[4:10] = ped_param
    
    The six binary grids are at indices 4 to 9 inclusive
    """
    # set up relevant policy and env
    if config.get('multiagent', {}).get('policies', None):
        multiagent = True
        rets = {}
        # map the agent id to its policy
        policy_map_fn = config['multiagent']['policy_mapping_fn']
        
#         policy_map_fn = config['multiagent']['policy_mapping_fn'].func
        for key in config['multiagent']['policies'].keys():
            rets[key] = []
    else:
        multiagent = False
        rets = []

    if config['model']['use_lstm']:
        use_lstm = True
        if multiagent:
            state_init = {}
            # map the agent id to its policy
#             policy_map_fn = config['multiagent']['policy_mapping_fn'].func

            policy_map_fn = config['multiagent']['policy_mapping_fn']
            size = config['model']['lstm_cell_size']
            for key in config['multiagent']['policies'].keys():
                state_init[key] = [np.zeros(size, np.float32),
                                   np.zeros(size, np.float32)]
        else:
            state_init = [
                np.zeros(config['model']['lstm_cell_size'], np.float32),
                np.zeros(config['model']['lstm_cell_size'], np.float32)
            ]
    else:
        use_lstm = False

    env.restart_simulation(
        sim_params=flow_params['sim'], render=flow_params['sim'].render)

    
    # Define variables to collect probability data. Each variable is dict
    # 2^6 keys (or, 2^5 values for p(o_i = b_i)) and values will be a list of numbers
    # TODO(KL) HARD CODED is_ped_visible is the 5th item in the state vector

    ped_idx_lst = [4, 5, 6, 7, 8, 9]
    ped_front = ped_idx_lst[0]
    ped_back = ped_idx_lst[-1]
    
    binary_observations = True
    
    
    # dict for f(a | o_i = b_i), where the key is bitstring s e.g.s = "010011", 
    # where s[i] corresponds to the value of b_i. cond_pdf_a_on_joint_ped["010011"] = list()
    
    # 1
    # IF binary_observations == True:
    cond_pdf_action_on_joint_ped_dct = make_dct_of_lsts(num_digits=len(ped_idx_lst), vals_per_dig=2)
    
    # 2
    # updated Pr(o_1 = b_1, ..., o_6 = b_6) for i = 1, ..., 6 and b_i = 0, 1
    updated_joint_prior_prob_ped_dct = initial_prior_probs(num_digits=6, vals_per_dig=2)
    # fixed Pr(o_1 = b_1, ..., o_6 = b_6) for i = 1, ..., 6 and b_i = 0, 1
    fixed_joint_prior_prob_ped_dct = initial_prior_probs(num_digits=6, vals_per_dig=2)
    
    # 3
    # updated joint cond_densities lst f(o_1 = b_1, ..., o_6 = b_6 | a)
    joint_cond_densities_updated_priors_dct = make_dct_of_lsts(num_digits=6, vals_per_dig=2)
    # fixed joint cond_densities lst f(o_1 = b_1, ..., o_6 = b_6 | a)
    joint_cond_densities_fixed_priors_dct = make_dct_of_lsts(num_digits=6, vals_per_dig=2)

    # 4
    # updated joint cond_probs lst p(o_1 = b_1, ..., o_6 = b_6 | a)
    joint_cond_probs_updated_priors_dct = make_dct_of_lsts(num_digits=6, vals_per_dig=2)
    # fixed joint cond_probs lst p(o_1 = b_1, ..., o_6 = b_6 | a)
    joint_cond_probs_fixed_priors_dct = make_dct_of_lsts(num_digits=6, vals_per_dig=2)
    
    # 5
    # updated single cond_probs lst p(o_i = b_i | a)
    single_cond_probs_updated_priors_lst = make_single_cond_prob_dct_of_lsts(num_variables=6, vals_per_var=2)
    # fixed single cond_probs lst p(o_i = b_i | a)
    single_cond_probs_fixed_priors_lst = make_single_cond_prob_dct_of_lsts(num_variables=6, vals_per_var=2)
    
    # 6
    # this will be the only variable that's a dict of lists
    visible_pedestrian_dct = {i : [] for i in range(1,7)}

    # each element in this list corresponds to a key 
    len_6_bitstring_lst = make_permutations(num_digits=6, vals_per_dig=2)
    for i in range(args.num_rollouts):
        state = env.reset()
        # divide by 5 to get "time" in the simulation
        for _ in range(1000):
            vehicles = env.unwrapped.k.vehicle
            pedestrian = env.unwrapped.k.pedestrian
            if multiagent:
                
                action, logits = {}, {}

                for agent_id in state.keys():
                    if use_lstm:
                        action[agent_id], state_init[agent_id], logits = \
                            agent.compute_action(state[agent_id], state=state_init[agent_id], policy_id=policy_map_fn(agent_id))
                    else:
                        s_all = state[agent_id]
                        # get ped visibility state array of length 6 from the rl car's POV
                        s_ped = s_all[ped_idx_lst]
                        
                        # update the visible_pedestrian dict
                        for idx, val in enumerate(s_ped, 1):
                            visible_pedestrian_dct[idx] = visible_pedestrian_dct[idx] + [val]
                            
                        # compute the actual action taken by the rl car
                        action[agent_id], _, logit_actual = agent.compute_action(state[agent_id], policy_id=policy_map_fn(agent_id), full_fetch=True)    
                        action_ = action[agent_id][0]
                        print(f'action is {action_}')
                        
                        # store variable for the sum of densities conditioned on the actual action
                        cond_density_sum_updated = 0
                        cond_density_sum_fixed = 0

                        # compute joint conditional densities for all possible permutations of ped visibility (ignore which permutation corresponds to the actual permutation for now)
                        for obs_comb in len_6_bitstring_lst:
                            s_all_modified = np.copy(s_all)
                            s_all_modified[ped_front : ped_back + 1] = list(obs_comb)
                            print(f'{s_all_modified[ped_front : ped_back + 1]} is list of length 6, {list(obs_comb)} has length 6')
                            action__, _, _ = agent.compute_action(state[agent_id], policy_id=policy_map_fn(agent_id), full_fetch=True)
                            # where in the docs did we figure out the logits were ln of sigma??
                            mu, sigma = action__, 0.5
                            # Eugene's suggestion is to set sigma as 0.5 because TD3 is deterministic
#                             print(f'logit is {logit}')
#                             import ipdb;ipdb.set_trace()
#                             mu, ln_sigma = logit['behaviour_logits']
#                             sigma = np.exp(ln_sigma)
                            
                            # 1
                            # compute the conditional a_given_obs pdfs, i.e. f(a | o_1 = b_1, ..., o_6 = b_6)
                            cond_a_given_joint_o_pdf = accel_pdf(mu, sigma, action_)[0]
                            # append new result to lists
                            cond_pdf_action_on_joint_ped_dct[obs_comb] = cond_pdf_action_on_joint_ped_dct[obs_comb] + [cond_a_given_joint_o_pdf]
                            # 2
                            # Get the updated and fixed priors
                            updated_prior = updated_joint_prior_prob_ped_dct[obs_comb][-1]
                            fixed_prior = 1 / 2**6
                            print(f'updated_prior is {updated_prior}, fixed prior is {fixed_prior}')
                            # 3
                            # compute the joint conditional obs_given_a pdfs, i.e. f(o_1 = b_1, ..., o_6 = b_6 | a)
                            cond_joint_o_given_a_pdf_updated = cond_a_given_joint_o_pdf * updated_prior
                            cond_joint_o_given_a_pdf_fixed = cond_a_given_joint_o_pdf * fixed_prior
                            # append new result to lists
                            joint_cond_densities_updated_priors_dct[obs_comb] = joint_cond_densities_updated_priors_dct[obs_comb] + [cond_joint_o_given_a_pdf_updated]
                            joint_cond_densities_fixed_priors_dct[obs_comb] = joint_cond_densities_fixed_priors_dct[obs_comb] + [cond_joint_o_given_a_pdf_fixed]

                            cond_density_sum_updated += cond_joint_o_given_a_pdf_updated
                            cond_density_sum_fixed += cond_joint_o_given_a_pdf_fixed
                            
                        # 4
                        # compute Pr(o_1 = b_1, ... o_6 = b_6 | a)
                        for obs_comb_ in len_6_bitstring_lst:
                            cond_joint_o_given_a_prob_updated = joint_cond_densities_updated_priors_dct[obs_comb_][-1] / cond_density_sum_updated
                            cond_joint_o_given_a_prob_fixed = joint_cond_densities_fixed_priors_dct[obs_comb_][-1] / cond_density_sum_fixed
                            # append to lists
                            joint_cond_probs_updated_priors_dct[obs_comb_] = joint_cond_probs_updated_priors_dct[obs_comb_] + [cond_joint_o_given_a_prob_updated]
                            joint_cond_probs_fixed_priors_dct[obs_comb_] = joint_cond_probs_fixed_priors_dct[obs_comb_] + [cond_joint_o_given_a_prob_fixed]
                        
                            # 2
                            # Update the updated and fixed priors lists
                            updated_joint_prior_prob_ped_dct[obs_comb_] = updated_joint_prior_prob_ped_dct[obs_comb_] + [cond_joint_o_given_a_prob_updated]
                            fixed_joint_prior_prob_ped_dct[obs_comb_] = fixed_joint_prior_prob_ped_dct[obs_comb_] + [cond_joint_o_given_a_prob_fixed]
                        
                        # 5
                        # compute Pr(o_i = b_i | a) for all i = 1, ..., 6
                        for grid_idx in range(1, 7):
                            for val in range(0, 2):
                                # compute the marginalization (4) - need to get the relevant ped observation combinations
                                single_cond_o_given_a_prob_updated = 0
                                single_cond_o_given_a_prob_fixed = 0

                                for key in get_ped_possiblities(grid_idx, val):
                                    single_cond_o_given_a_prob_updated += joint_cond_probs_updated_priors_dct[key][-1]
                                    single_cond_o_given_a_prob_fixed += joint_cond_probs_fixed_priors_dct[key][-1]
                                
                                single_cond_prob_str = single_cond_prob_to_str(grid_idx, val)
                                # append to list
#                                 import ipdb;ipdb.set_trace()
                                single_cond_probs_updated_priors_lst[single_cond_prob_str] = single_cond_probs_updated_priors_lst[single_cond_prob_str] + [single_cond_o_given_a_prob_updated]
                                single_cond_probs_fixed_priors_lst[single_cond_prob_str] = single_cond_probs_fixed_priors_lst[single_cond_prob_str] + [single_cond_o_given_a_prob_fixed]
                                
                    print(updated_joint_prior_prob_ped_dct == fixed_joint_prior_prob_ped_dct, 9999)
            else:
                action = agent.compute_action(state)
            state, reward, done, _ = env.step(action)

            if multiagent and done['__all__']:
                print(_,1)
                break
            if not multiagent and done:
                print(_,1)

                break    
            state, reward, done, _ = env.step(action)   

        visible_ped_lsts = [visible_pedestrian_dct[i] for i in range(1, 7)]
        legends = [f'ped in grid {i}' for i in range(1, 7)]
        joint_cond_probs_updated_priors_dct['000000'], joint_cond_probs_updated_priors_dct['000001']

        for grid_idx in range(1, 7):
            for val in range(0, 2):
                single_cond_prob_str = single_cond_prob_to_str(grid_idx, val)
                a_ = single_cond_probs_updated_priors_lst[single_cond_prob_str]
                b_ = single_cond_probs_fixed_priors_lst[single_cond_prob_str]

                plot_2_lines(a_, b_, [f'Pr(ped in grid {grid_idx} = {val}) using updated priors', f'Pr(ped in grid {grid_idx} = {val}) using fixed priors'])
#         plot_lines(visible_ped_lsts, legends)
#         plot_2_lines(probs_ped_given_action_updated_priors, probs_no_ped_given_action_updated_priors, ['Pr(ped | action) using updated priors', 'Pr(no_ped | action) using updated priors'], viewable_ped=visible_pedestrian[4])
#         plot_2_lines(probs_ped_given_action_fixed_priors, probs_no_ped_given_action_fixed_priors, ['Pr(ped | action) using fixed priors of Pr(ped) = 0.5', 'Pr(no_ped | action) using fixed priors of Pr(ped) = 0.5'], viewable_ped=visible_pedestrian[5])
#         plot_2_lines(probs_action_given_ped, probs_action_given_no_ped, ['Pr(action | ped)', 'Pr(action | no_ped)'], viewable_ped=visible_pedestrian[6])
#         priors_len = len(joint_cond_probs_updated_priors_dct['000000'])
#         plt.plot(joint_cond_probs_updated_priors_dct['000000'])
#         plt.plot(joint_cond_probs_updated_priors_dct['000001'])
        fig = plt.figure(figsize=(15, 15))

        y1 = visible_pedestrian_dct[1]
        y2 = visible_pedestrian_dct[2]
        y3 = visible_pedestrian_dct[3]
        y4 = visible_pedestrian_dct[4]
        y5 = visible_pedestrian_dct[5]
        y6 = visible_pedestrian_dct[6]

        vis_ped_1 = plt.subplot(2, 2, 1)
        plt.plot(y1, 'o-')
        vis_ped_1.set_title('Pedestrian in grid 1')
        vis_ped_1.set_xlabel('time (s)')
        vis_ped_1.set_ylabel('in grid 1?')

        vis_ped_2 = plt.subplot(2, 2, 3)
        vis_ped_2.plot(y2, '.-')
        vis_ped_2.set_title('Pedestrian in grid 2')

        vis_ped_2.set_xlabel('time (s)')
        vis_ped_2.set_ylabel('in grid 2?')


#         plot_2_lines(joint_cond_probs_updated_priors_dct['000000'], [1/(2^6)] * priors_len , [f'updated prior of p(000000))', f'fixed prior of p(000000)'] )

# %%
def single_cond_prob_to_str(grid_idx, val, num_indices = 6):
    """Generate the string representing the probability:
    
    Pr(o_i = val)
    
    ex:
    For Pr(o_2 = 1), we'd have the string '21'
    NB we're 1-indexing here
    """
    assert grid_idx >= 1 and grid_idx <= num_indices
    return str(grid_idx) + str(val)

def get_ped_possiblities(grid_idx, val, output_len=6):
    """Give the single probability we want, compute the list of all bitstrings we need to perform the marginalization.
    
    ex:
    3:0 means we want p(o_3 = 0 | a)
    Therefore, we can get the list of all possible length 5 bitstrings, and stitch '0' in the correct place.
    
    
    @Return
    NB 1-indexing here
    bitstring of length 6
    """
    
    assert grid_idx >= 1 and grid_idx <= output_len
    res = []
    res_lst = make_permutations(output_len - 1, 2)
    
    for perm in res_lst:
        res.append(str(perm[:grid_idx - 1:] + str(val) + perm[grid_idx - 1:]))
        
    return res

def initial_prior_probs(num_digits=6, vals_per_dig=2):
    """Returns a dict with values of all permutations of bitstrings of length num_digits. 
    Each digit can take a value from 0 to (vals_per_dig - 1)"""
    uniform_prob = 1 / (vals_per_dig ** num_digits)
    res = make_dct_of_lsts(num_digits, vals_per_dig)
    for key in res.keys():
        res[key] = res[key] + [uniform_prob]
    return res

def make_dct_of_lsts(num_digits=6, vals_per_dig=2):
    """Return a dict with keys of bitstrings and values as empty lists. 
    Hardcoded for binary vals per var."""
    res = {}
    lst_of_bitstrings = make_permutations(num_digits, vals_per_dig)
        
    return {str_ : [] for str_ in lst_of_bitstrings}

def make_permutations(num_digits, vals_per_dig=2):
    """Make all permutations for a bit string of length num_digits
    and vals_per_dig values per digit. Hardcoded for work for binary vals per var"""
    if num_digits == 1:
        return [str(i) for i in range(vals_per_dig)]
    else:
        small_perms = make_permutations(num_digits - 1, vals_per_dig)
        # hardcoded for work for binary vals per var
        return ['0' + bit_str for bit_str in small_perms] + ['1' + bit_str for bit_str in small_perms]
    
def make_single_cond_prob_dct_of_lsts(num_variables=6, vals_per_var=2):
    """@Params
    num_variables = number of states that we care about
    
    @Returns
    dict of lists. Keys have the format: 'o_{i}={val}', where val is either '0' or '1'
    """
    res = {}
    for i in range(1, num_variables + 1):
        for val in range(vals_per_var):
            res[f'{i}{val}'] = []
    return res

# %% [markdown]
# ## Helper function testing suite

# %% [markdown]
# Define indicator RVs $G_i$, where $G_i = 1$ if there's a pedestrian in grid cell $i$ and $0$ if not.
#
# Want $Pr(G_i = 1 | action) = \frac{Pr(action | G_i = 1) Pr(G_i = 1)}{Pr(G_i = 1)}$
#
# Consider grid 1:
# $\begin{equation} \label{eq1}
# \begin{split}
# Pr(action | G_1 = 1) & = \frac{Pr(action, G_1 = 1)}{Pr(G_1 = 1)} \\
#  & = \frac{\sum_{g2 \in \{0, 1\}} \sum_{g3 \in \{0, 1\}} \sum_{g4 \in \{0, 1\}} \sum_{g5 \in \{0, 1\}} \sum_{g6 \in \{0, 1\}} Pr(action, G_1 = 1, G_2 = g2, G_3 = g3, G_4 = g4, G_5 = g5, G_6 = g6)}{Pr(G_1 = 1)} \\
#  & = \frac{\sum_{g2 \in \{0, 1\}} \sum_{g3 \in \{0, 1\}} \sum_{g4 \in \{0, 1\}} \sum_{g5 \in \{0, 1\}} \sum_{g6 \in \{0, 1\}} Pr(action | G_1 = 1, G_2 = g2, G_3 = g3, G_4 = g4, G_5 = g5, G_6 = g6) Pr(G_1 = 1, G_2 = g2, G_3 = g3, G_4 = g4, G_5 = g5, G_6 = g6))}{Pr(G_1 = 1)}
# \end{split}
# \end{equation}$
#
# The policy doesn't actually output a probability; the policy outputs a probability density.
# i.e. instead of outputting $Pr(action | G_1 = 1, G_2 = g2, G_3 = g3, G_4 = g4, G_5 = g5, G_6 = g6)$,
# the policy outputs $f(action | G_1 = 1, G_2 = g2, G_3 = g3, G_4 = g4, G_5 = g5, G_6 = g6)$
#
# Perhaps after some handwaving and assumptions about $Pr(G_i = 0) = 0.5$, I could say, I have $f(action | G_1 = 1) \sim \sum \sum \sum \ldots \ldots = k_1$. Note, I don't have equality here. Under the assumption of $Pr(G_i = 0) = 0.5$, the numerator joint probability / density term (assuming independence) is $0.5^6$.
#
# How do I convert these $k_i$'s into probabilities?
#
# Is it feasible to normalize just the 6 $f(action | G_i = 1)$ values, i.e assert
#
# $Pr(action | G_1 = 1) = \frac{f(action | G_1 = 1)}{\sum_{i=1}^6 f(action | G_i = 1)}$?
#
# I don't think this normalization is accurate. It seems more accurate to do:
#
# $Pr(action | G_1 = 1) = \frac{f(action | G_1 = 1)}{f(action | G_1 = 1) + f(action | G_1 = 0)}$?
#
# My doubts are:
#
# 1. the conversion from pdfs to probabilities - is this how we normalize pdfs to get probabilities?

# %%
def pr_ped_given_action(action, mu_ped, s_ped, mu_no_ped, s_no_ped, prior, fixed_prior=True):
    """
    @Params
    mu_ped, s_ped: mean, sd pair from the policy receiving an input state where there is a visible pedestrian 
    mu_no_ped, s_no_ped: mean, sd pair from the policy receiving an input state where there is no visible pedestrian 

    action: the vehicle's acceleration as dictated by the policy
    prior: Pr(ped)
    fixed_prior: Boolean telling us whether to 'update' the prior Pr(ped) using Pr(ped | action) or not

    @Returns
    
    probs, a dict containing:
    1. Pr(action | ped)
    2. Pr(action | no_ped)
    3. Pr(ped | action)
    4. Pr(no_ped | action)
    5. Pr(ped) for the next computation of Pr(ped|action)
    
    3, 4, 5 are calculated subject to the fixed_prior parameter
    """
    probs = {}
    
    # Compute 1, 2: Pr(action | ped), Pr(action | no_ped)
    unnormed_pr_action_given_ped = accel_pdf(mu_ped, s_ped, action)
    unnormed_pr_action_given_no_ped = accel_pdf(mu_no_ped, s_no_ped, action)
    
    pr_a_given_ped = unnormed_pr_action_given_ped / (unnormed_pr_action_given_ped + unnormed_pr_action_given_no_ped)
    pr_a_given_no_ped = 1 - pr_a_given_ped
    
    probs["pr_a_given_ped"] = pr_a_given_ped
    probs["pr_a_given_no_ped"] = pr_a_given_no_ped
    
    # Compute 3, 4: Pr(ped | action), Pr(no_ped | action)
    # Apply Bayes' rule
    pr_ped_given_action = (pr_a_given_ped * prior) / ((pr_a_given_ped * prior)  + (pr_a_given_no_ped * (1 - prior)))
    pr_no_ped_given_action = (pr_a_given_no_ped * (1 - prior)) / ((pr_a_given_ped * prior)  + (pr_a_given_no_ped * (1 - prior)))
    probs["pr_ped_given_action"] = pr_ped_given_action
    probs["pr_no_ped_given_action"] = pr_no_ped_given_action
                    
    if fixed_prior:
        probs["prior"] = prior
    else:
        probs["prior"] = probs["pr_ped_given_action"]
    return probs
    

def accel_pdf(mu, sigma, actual):
    """Return pdf evaluated at actual acceleration"""
    coeff = 1 / np.sqrt(2 * np.pi * (sigma**2))
    exp = -0.5 * ((actual - mu) / sigma)**2
    return coeff * np.exp(exp)

def run_transfer(args):
    # run transfer on the bayesian 1 env first
    bayesian_0_params = bayesian_0_flow_params(args, pedestrians=True, render=True)
#     import ipdb; ipdb.set_trace()
    env, env_name = create_env(args, bayesian_0_params)
    agent, config = create_agent(args, flow_params=bayesian_0_params)
    run_env(env, agent, config, bayesian_0_params)

def plot_2_lines(y1, y2, legend, viewable_ped=False):
    x = np.arange(len(y1))
    plt.plot(x, y1)
    plt.plot(x, y2)
    if viewable_ped:
        plt.plot(x, viewable_ped)
    plt.legend(legend, bbox_to_anchor=(0.5, 1.05), loc=3, borderaxespad=0.)
   
    plt.draw()
    plt.pause(0.001)
    
def plot_lines(y_val_lsts, legends):
    assert len(y_val_lsts) == len(legends)
    x = np.arange(len(y_val_lsts[0]))
    for y_vals in y_val_lsts:
        plt.plot(x, y_vals)
    plt.legend(legends, bbox_to_anchor=(0.5, 1.05), loc=3, borderaxespad=0.)
    plt.draw()
    plt.pause(0.001)

# %%
def create_parser():
    """Create the parser to capture CLI arguments."""
    parser = argparse.ArgumentParser(
        formatter_class=argparse.RawDescriptionHelpFormatter,
        description='[Flow] Evaluates a reinforcement learning agent '
                    'given a checkpoint.',
        epilog=EXAMPLE_USAGE)

    # required input parameters
    parser.add_argument(
        'result_dir', type=str, help='Directory containing results')
    parser.add_argument('checkpoint_num', type=str, help='Checkpoint number.')

    # optional input parameters
    parser.add_argument(
        '--run',
        type=str,
        help='The algorithm or model to train. This may refer to '
             'the name of a built-on algorithm (e.g. RLLib\'s DQN '
             'or PPO), or a user-defined trainable function or '
             'class registered in the tune registry. '
             'Required for results trained with flow-0.2.0 and before.')
    parser.add_argument(
        '--num_rollouts',
        type=int,
        default=1,
        help='The number of rollouts to visualize.')
    parser.add_argument(
        '--gen_emission',
        action='store_true',
        help='Specifies whether to generate an emission file from the '
             'simulation')
    parser.add_argument(
        '--evaluate',
        action='store_true',
        help='Specifies whether to use the \'evaluate\' reward '
             'for the environment.')
    parser.add_argument(
        '--render_mode',
        type=str,
        default='sumo_gui',
        help='Pick the render mode. Options include sumo_web3d, '
             'rgbd and sumo_gui')
    parser.add_argument(
        '--save_render',
        action='store_true',
        help='Saves a rendered video to a file. NOTE: Overrides render_mode '
             'with pyglet rendering.')
    parser.add_argument(
        '--horizon',
        type=int,
        help='Specifies the horizon.')
    
    parser.add_argument('--grid_search', action='store_true', default=False,
                        help='If true, a grid search is run')
    parser.add_argument('--run_mode', type=str, default='local',
                        help="Experiment run mode (local | cluster)")
    parser.add_argument('--algo', type=str, default='TD3',
                        help="RL method to use (PPO, TD3, MADDPG)")
    parser.add_argument("--pedestrians",
                        help="use pedestrians, sidewalks, and crossings in the simulation",
                        action="store_true")
    
    return parser

# %%
parser = create_parser()
args = parser.parse_args(["./TD3_Bayesian1Env-latest", "250"])
ray.shutdown()
ray.init(num_cpus=1)
run_transfer(args)
# Out:
# 2020-04-11 23:40:21,668	WARNING services.py:597 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2020-04-11 23:40:21,669	INFO resource_spec.py:216 -- Starting Ray with 4.05 GiB memory available for workers and up to 2.03 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# NOTE: With render mode sumo_gui, an extra instance of the SUMO GUI will display before the GUI for visualizing the result. Click the green Play arrow to continue.
# (2.1)--(1.1) (1.1)--(1.2) 1 1
# Error making env  Cannot re-register id: Bayesian1Env-v0
# True
# NOTE: With render mode sumo_gui, an extra instance of the SUMO GUI will display before the GUI for visualizing the result. Click the green Play arrow to continue.
# (2.1)--(1.1) (1.1)--(1.2) 1 1
# Error making env  Cannot re-register id: Bayesian1Env-v0
# True
# (2.1)--(1.1) (1.1)--(1.2) 1 1
# Error making env  Cannot re-register id: Bayesian1Env-v0
# True
# 2020-04-11 23:40:26,482	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# 2020-04-11 23:40:26,524	INFO trainable.py:346 -- Restored from checkpoint: ./TD3_Bayesian1Env-latest/checkpoint_250/checkpoint-250
# 2020-04-11 23:40:26,525	INFO trainable.py:353 -- Current state after restoring: {'_iteration': 250, '_timesteps_total': 256162, '_time_total': 4479.650965929031, '_episodes_total': 572}
#  Retrying in 1 seconds
# departtime is 10.00
# state in train.py's compute_action is None
# action is 2.5999999046325684
# [0. 0. 0. 0. 0. 0.] is list of length 6, ['0', '0', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 0. 0. 0. 0. 1.] is list of length 6, ['0', '0', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 0. 0. 0. 1. 0.] is list of length 6, ['0', '0', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 0. 0. 0. 1. 1.] is list of length 6, ['0', '0', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 0. 0. 1. 0. 0.] is list of length 6, ['0', '0', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 0. 0. 1. 0. 1.] is list of length 6, ['0', '0', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 0. 0. 1. 1. 0.] is list of length 6, ['0', '0', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 0. 0. 1. 1. 1.] is list of length 6, ['0', '0', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 0. 1. 0. 0. 0.] is list of length 6, ['0', '0', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 0. 1. 0. 0. 1.] is list of length 6, ['0', '0', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 0. 1. 0. 1. 0.] is list of length 6, ['0', '0', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 0. 1. 0. 1. 1.] is list of length 6, ['0', '0', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 0. 1. 1. 0. 0.] is list of length 6, ['0', '0', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 0. 1. 1. 0. 1.] is list of length 6, ['0', '0', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 0. 1. 1. 1. 0.] is list of length 6, ['0', '0', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 0. 1. 1. 1. 1.] is list of length 6, ['0', '0', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 1. 0. 0. 0. 0.] is list of length 6, ['0', '1', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 1. 0. 0. 0. 1.] is list of length 6, ['0', '1', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 1. 0. 0. 1. 0.] is list of length 6, ['0', '1', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 1. 0. 0. 1. 1.] is list of length 6, ['0', '1', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 1. 0. 1. 0. 0.] is list of length 6, ['0', '1', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 1. 0. 1. 0. 1.] is list of length 6, ['0', '1', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 1. 0. 1. 1. 0.] is list of length 6, ['0', '1', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 1. 0. 1. 1. 1.] is list of length 6, ['0', '1', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 1. 1. 0. 0. 0.] is list of length 6, ['0', '1', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 1. 1. 0. 0. 1.] is list of length 6, ['0', '1', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 1. 1. 0. 1. 0.] is list of length 6, ['0', '1', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 1. 1. 0. 1. 1.] is list of length 6, ['0', '1', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 1. 1. 1. 0. 0.] is list of length 6, ['0', '1', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 1. 1. 1. 0. 1.] is list of length 6, ['0', '1', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 1. 1. 1. 1. 0.] is list of length 6, ['0', '1', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [0. 1. 1. 1. 1. 1.] is list of length 6, ['0', '1', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 0. 0. 0. 0. 0.] is list of length 6, ['1', '0', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 0. 0. 0. 0. 1.] is list of length 6, ['1', '0', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 0. 0. 0. 1. 0.] is list of length 6, ['1', '0', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 0. 0. 0. 1. 1.] is list of length 6, ['1', '0', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 0. 0. 1. 0. 0.] is list of length 6, ['1', '0', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 0. 0. 1. 0. 1.] is list of length 6, ['1', '0', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 0. 0. 1. 1. 0.] is list of length 6, ['1', '0', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 0. 0. 1. 1. 1.] is list of length 6, ['1', '0', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 0. 1. 0. 0. 0.] is list of length 6, ['1', '0', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 0. 1. 0. 0. 1.] is list of length 6, ['1', '0', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 0. 1. 0. 1. 0.] is list of length 6, ['1', '0', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 0. 1. 0. 1. 1.] is list of length 6, ['1', '0', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 0. 1. 1. 0. 0.] is list of length 6, ['1', '0', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 0. 1. 1. 0. 1.] is list of length 6, ['1', '0', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 0. 1. 1. 1. 0.] is list of length 6, ['1', '0', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 0. 1. 1. 1. 1.] is list of length 6, ['1', '0', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 1. 0. 0. 0. 0.] is list of length 6, ['1', '1', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 1. 0. 0. 0. 1.] is list of length 6, ['1', '1', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 1. 0. 0. 1. 0.] is list of length 6, ['1', '1', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 1. 0. 0. 1. 1.] is list of length 6, ['1', '1', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 1. 0. 1. 0. 0.] is list of length 6, ['1', '1', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 1. 0. 1. 0. 1.] is list of length 6, ['1', '1', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 1. 0. 1. 1. 0.] is list of length 6, ['1', '1', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 1. 0. 1. 1. 1.] is list of length 6, ['1', '1', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 1. 1. 0. 0. 0.] is list of length 6, ['1', '1', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 1. 1. 0. 0. 1.] is list of length 6, ['1', '1', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 1. 1. 0. 1. 0.] is list of length 6, ['1', '1', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 1. 1. 0. 1. 1.] is list of length 6, ['1', '1', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 1. 1. 1. 0. 0.] is list of length 6, ['1', '1', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 1. 1. 1. 0. 1.] is list of length 6, ['1', '1', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 1. 1. 1. 1. 0.] is list of length 6, ['1', '1', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# [1. 1. 1. 1. 1. 1.] is list of length 6, ['1', '1', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015625, fixed prior is 0.015625
# True 9999
# state in train.py's compute_action is None
# action is 2.5999999046325684
# [0. 0. 0. 0. 0. 0.] is list of length 6, ['0', '0', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015284858632740842, fixed prior is 0.015625
# [0. 0. 0. 0. 0. 1.] is list of length 6, ['0', '0', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015589287331765648, fixed prior is 0.015625
# [0. 0. 0. 0. 1. 0.] is list of length 6, ['0', '0', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015634627675547904, fixed prior is 0.015625
# [0. 0. 0. 0. 1. 1.] is list of length 6, ['0', '0', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015527837131376458, fixed prior is 0.015625
# [0. 0. 0. 1. 0. 0.] is list of length 6, ['0', '0', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01583911559747414, fixed prior is 0.015625
# [0. 0. 0. 1. 0. 1.] is list of length 6, ['0', '0', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015632540544654457, fixed prior is 0.015625
# [0. 0. 0. 1. 1. 0.] is list of length 6, ['0', '0', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01564991830664249, fixed prior is 0.015625
# [0. 0. 0. 1. 1. 1.] is list of length 6, ['0', '0', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [0. 0. 1. 0. 0. 0.] is list of length 6, ['0', '0', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01584040717989317, fixed prior is 0.015625
# [0. 0. 1. 0. 0. 1.] is list of length 6, ['0', '0', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015846550187383866, fixed prior is 0.015625
# [0. 0. 1. 0. 1. 0.] is list of length 6, ['0', '0', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01583452935522728, fixed prior is 0.015625
# [0. 0. 1. 0. 1. 1.] is list of length 6, ['0', '0', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [0. 0. 1. 1. 0. 0.] is list of length 6, ['0', '0', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [0. 0. 1. 1. 0. 1.] is list of length 6, ['0', '0', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [0. 0. 1. 1. 1. 0.] is list of length 6, ['0', '0', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [0. 0. 1. 1. 1. 1.] is list of length 6, ['0', '0', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [0. 1. 0. 0. 0. 0.] is list of length 6, ['0', '1', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015844570787012995, fixed prior is 0.015625
# [0. 1. 0. 0. 0. 1.] is list of length 6, ['0', '1', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [0. 1. 0. 0. 1. 0.] is list of length 6, ['0', '1', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [0. 1. 0. 0. 1. 1.] is list of length 6, ['0', '1', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015664412205410767, fixed prior is 0.015625
# [0. 1. 0. 1. 0. 0.] is list of length 6, ['0', '1', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [0. 1. 0. 1. 0. 1.] is list of length 6, ['0', '1', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015580970772193066, fixed prior is 0.015625
# [0. 1. 0. 1. 1. 0.] is list of length 6, ['0', '1', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [0. 1. 0. 1. 1. 1.] is list of length 6, ['0', '1', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [0. 1. 1. 0. 0. 0.] is list of length 6, ['0', '1', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014808366531381754, fixed prior is 0.015625
# [0. 1. 1. 0. 0. 1.] is list of length 6, ['0', '1', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [0. 1. 1. 0. 1. 0.] is list of length 6, ['0', '1', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [0. 1. 1. 0. 1. 1.] is list of length 6, ['0', '1', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847197754371226, fixed prior is 0.015625
# [0. 1. 1. 1. 0. 0.] is list of length 6, ['0', '1', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015593159711318947, fixed prior is 0.015625
# [0. 1. 1. 1. 0. 1.] is list of length 6, ['0', '1', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01581793885475039, fixed prior is 0.015625
# [0. 1. 1. 1. 1. 0.] is list of length 6, ['0', '1', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015583501847547683, fixed prior is 0.015625
# [0. 1. 1. 1. 1. 1.] is list of length 6, ['0', '1', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [1. 0. 0. 0. 0. 0.] is list of length 6, ['1', '0', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [1. 0. 0. 0. 0. 1.] is list of length 6, ['1', '0', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015647908126122316, fixed prior is 0.015625
# [1. 0. 0. 0. 1. 0.] is list of length 6, ['1', '0', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015788726125353512, fixed prior is 0.015625
# [1. 0. 0. 0. 1. 1.] is list of length 6, ['1', '0', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014823671368699099, fixed prior is 0.015625
# [1. 0. 0. 1. 0. 0.] is list of length 6, ['1', '0', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [1. 0. 0. 1. 0. 1.] is list of length 6, ['1', '0', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015829412747330813, fixed prior is 0.015625
# [1. 0. 0. 1. 1. 0.] is list of length 6, ['1', '0', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015821141174130294, fixed prior is 0.015625
# [1. 0. 0. 1. 1. 1.] is list of length 6, ['1', '0', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015822837633897913, fixed prior is 0.015625
# [1. 0. 1. 0. 0. 0.] is list of length 6, ['1', '0', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [1. 0. 1. 0. 0. 1.] is list of length 6, ['1', '0', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [1. 0. 1. 0. 1. 0.] is list of length 6, ['1', '0', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [1. 0. 1. 0. 1. 1.] is list of length 6, ['1', '0', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015332498016906011, fixed prior is 0.015625
# [1. 0. 1. 1. 0. 0.] is list of length 6, ['1', '0', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.013025930703636486, fixed prior is 0.015625
# [1. 0. 1. 1. 0. 1.] is list of length 6, ['1', '0', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [1. 0. 1. 1. 1. 0.] is list of length 6, ['1', '0', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.013941440074572441, fixed prior is 0.015625
# [1. 0. 1. 1. 1. 1.] is list of length 6, ['1', '0', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [1. 1. 0. 0. 0. 0.] is list of length 6, ['1', '1', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [1. 1. 0. 0. 0. 1.] is list of length 6, ['1', '1', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015048779622957757, fixed prior is 0.015625
# [1. 1. 0. 0. 1. 0.] is list of length 6, ['1', '1', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01569222443801414, fixed prior is 0.015625
# [1. 1. 0. 0. 1. 1.] is list of length 6, ['1', '1', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014906363423666347, fixed prior is 0.015625
# [1. 1. 0. 1. 0. 0.] is list of length 6, ['1', '1', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015595277622361702, fixed prior is 0.015625
# [1. 1. 0. 1. 0. 1.] is list of length 6, ['1', '1', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [1. 1. 0. 1. 1. 0.] is list of length 6, ['1', '1', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015709865015123187, fixed prior is 0.015625
# [1. 1. 0. 1. 1. 1.] is list of length 6, ['1', '1', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015776108631841115, fixed prior is 0.015625
# [1. 1. 1. 0. 0. 0.] is list of length 6, ['1', '1', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015138261068551161, fixed prior is 0.015625
# [1. 1. 1. 0. 0. 1.] is list of length 6, ['1', '1', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015395969052482446, fixed prior is 0.015625
# [1. 1. 1. 0. 1. 0.] is list of length 6, ['1', '1', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [1. 1. 1. 0. 1. 1.] is list of length 6, ['1', '1', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015660042608060958, fixed prior is 0.015625
# [1. 1. 1. 1. 0. 0.] is list of length 6, ['1', '1', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015744618171395462, fixed prior is 0.015625
# [1. 1. 1. 1. 0. 1.] is list of length 6, ['1', '1', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [1. 1. 1. 1. 1. 0.] is list of length 6, ['1', '1', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# [1. 1. 1. 1. 1. 1.] is list of length 6, ['1', '1', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015847375332155696, fixed prior is 0.015625
# False 9999
# state in train.py's compute_action is None
# action is 2.5999999046325684
# [0. 0. 0. 0. 0. 0.] is list of length 6, ['0', '0', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014727505830930817, fixed prior is 0.015625
# [0. 0. 0. 0. 0. 1.] is list of length 6, ['0', '0', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015701235584387782, fixed prior is 0.015625
# [0. 0. 0. 0. 1. 0.] is list of length 6, ['0', '0', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.013942858925970551, fixed prior is 0.015625
# [0. 0. 0. 0. 1. 1.] is list of length 6, ['0', '0', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015308050071768954, fixed prior is 0.015625
# [0. 0. 0. 1. 0. 0.] is list of length 6, ['0', '0', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01597237967605655, fixed prior is 0.015625
# [0. 0. 0. 1. 0. 1.] is list of length 6, ['0', '0', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01565544684400362, fixed prior is 0.015625
# [0. 0. 0. 1. 1. 0.] is list of length 6, ['0', '0', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015615289622436863, fixed prior is 0.015625
# [0. 0. 0. 1. 1. 1.] is list of length 6, ['0', '0', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598070890489167, fixed prior is 0.015625
# [0. 0. 1. 0. 0. 0.] is list of length 6, ['0', '0', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015973682125341216, fixed prior is 0.015625
# [0. 0. 1. 0. 0. 1.] is list of length 6, ['0', '0', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01597987681767681, fixed prior is 0.015625
# [0. 0. 1. 0. 1. 0.] is list of length 6, ['0', '0', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01586967438859621, fixed prior is 0.015625
# [0. 0. 1. 0. 1. 1.] is list of length 6, ['0', '0', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015564602025406632, fixed prior is 0.015625
# [0. 0. 1. 1. 0. 0.] is list of length 6, ['0', '0', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598070890489167, fixed prior is 0.015625
# [0. 0. 1. 1. 0. 1.] is list of length 6, ['0', '0', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598070890489167, fixed prior is 0.015625
# [0. 0. 1. 1. 1. 0.] is list of length 6, ['0', '0', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015703672808650072, fixed prior is 0.015625
# [0. 0. 1. 1. 1. 1.] is list of length 6, ['0', '0', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598070890489167, fixed prior is 0.015625
# [0. 1. 0. 0. 0. 0.] is list of length 6, ['0', '1', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015564037781279894, fixed prior is 0.015625
# [0. 1. 0. 0. 0. 1.] is list of length 6, ['0', '1', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598070890489167, fixed prior is 0.015625
# [0. 1. 0. 0. 1. 0.] is list of length 6, ['0', '1', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015369576063041675, fixed prior is 0.015625
# [0. 1. 0. 0. 1. 1.] is list of length 6, ['0', '1', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01579620639847935, fixed prior is 0.015625
# [0. 1. 0. 1. 0. 0.] is list of length 6, ['0', '1', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598070890489167, fixed prior is 0.015625
# [0. 1. 0. 1. 0. 1.] is list of length 6, ['0', '1', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015221536688561486, fixed prior is 0.015625
# [0. 1. 0. 1. 1. 0.] is list of length 6, ['0', '1', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598070890489167, fixed prior is 0.015625
# [0. 1. 0. 1. 1. 1.] is list of length 6, ['0', '1', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598070890489167, fixed prior is 0.015625
# [0. 1. 1. 0. 0. 0.] is list of length 6, ['0', '1', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014760068264998288, fixed prior is 0.015625
# [0. 1. 1. 0. 0. 1.] is list of length 6, ['0', '1', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015964332186938372, fixed prior is 0.015625
# [0. 1. 1. 0. 1. 0.] is list of length 6, ['0', '1', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015740802760668113, fixed prior is 0.015625
# [0. 1. 1. 0. 1. 1.] is list of length 6, ['0', '1', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598052983303768, fixed prior is 0.015625
# [0. 1. 1. 1. 0. 0.] is list of length 6, ['0', '1', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01572435441397322, fixed prior is 0.015625
# [0. 1. 1. 1. 0. 1.] is list of length 6, ['0', '1', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015951024760562413, fixed prior is 0.015625
# [0. 1. 1. 1. 1. 0.] is list of length 6, ['0', '1', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015125598464567869, fixed prior is 0.015625
# [0. 1. 1. 1. 1. 1.] is list of length 6, ['0', '1', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015786209413777435, fixed prior is 0.015625
# [1. 0. 0. 0. 0. 0.] is list of length 6, ['1', '0', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01591089595189627, fixed prior is 0.015625
# [1. 0. 0. 0. 0. 1.] is list of length 6, ['1', '0', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015779563460369794, fixed prior is 0.015625
# [1. 0. 0. 0. 1. 0.] is list of length 6, ['1', '0', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01592156624676918, fixed prior is 0.015625
# [1. 0. 0. 0. 1. 1.] is list of length 6, ['1', '0', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014928854206847813, fixed prior is 0.015625
# [1. 0. 0. 1. 0. 0.] is list of length 6, ['1', '0', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598070890489167, fixed prior is 0.015625
# [1. 0. 0. 1. 0. 1.] is list of length 6, ['1', '0', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01592635158488172, fixed prior is 0.015625
# [1. 0. 0. 1. 1. 0.] is list of length 6, ['1', '0', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015848241394463912, fixed prior is 0.015625
# [1. 0. 0. 1. 1. 1.] is list of length 6, ['1', '0', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01490017320544113, fixed prior is 0.015625
# [1. 0. 1. 0. 0. 0.] is list of length 6, ['1', '0', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015933849382140333, fixed prior is 0.015625
# [1. 0. 1. 0. 0. 1.] is list of length 6, ['1', '0', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598070890489167, fixed prior is 0.015625
# [1. 0. 1. 0. 1. 0.] is list of length 6, ['1', '0', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598070890489167, fixed prior is 0.015625
# [1. 0. 1. 0. 1. 1.] is list of length 6, ['1', '0', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015461499614755037, fixed prior is 0.015625
# [1. 0. 1. 1. 0. 0.] is list of length 6, ['1', '0', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.013135525752818098, fixed prior is 0.015625
# [1. 0. 1. 1. 0. 1.] is list of length 6, ['1', '0', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598070890489167, fixed prior is 0.015625
# [1. 0. 1. 1. 1. 0.] is list of length 6, ['1', '0', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014058737858922601, fixed prior is 0.015625
# [1. 0. 1. 1. 1. 1.] is list of length 6, ['1', '0', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015919794629227067, fixed prior is 0.015625
# [1. 1. 0. 0. 0. 0.] is list of length 6, ['1', '1', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598070890489167, fixed prior is 0.015625
# [1. 1. 0. 0. 0. 1.] is list of length 6, ['1', '1', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015175394126015176, fixed prior is 0.015625
# [1. 1. 0. 0. 1. 0.] is list of length 6, ['1', '1', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015824252632250804, fixed prior is 0.015625
# [1. 1. 0. 0. 1. 1.] is list of length 6, ['1', '1', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015031779692929903, fixed prior is 0.015625
# [1. 1. 0. 1. 0. 0.] is list of length 6, ['1', '1', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01562702506790499, fixed prior is 0.015625
# [1. 1. 0. 1. 0. 1.] is list of length 6, ['1', '1', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598070890489167, fixed prior is 0.015625
# [1. 1. 0. 1. 1. 0.] is list of length 6, ['1', '1', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01583707940990544, fixed prior is 0.015625
# [1. 1. 0. 1. 1. 1.] is list of length 6, ['1', '1', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015908842594637214, fixed prior is 0.015625
# [1. 1. 1. 0. 0. 0.] is list of length 6, ['1', '1', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015067746219838696, fixed prior is 0.015625
# [1. 1. 1. 0. 0. 1.] is list of length 6, ['1', '1', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015525504670619455, fixed prior is 0.015625
# [1. 1. 1. 0. 1. 0.] is list of length 6, ['1', '1', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598070890489167, fixed prior is 0.015625
# [1. 1. 1. 0. 1. 1.] is list of length 6, ['1', '1', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015791800037058906, fixed prior is 0.015625
# [1. 1. 1. 1. 0. 0.] is list of length 6, ['1', '1', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015877087185863507, fixed prior is 0.015625
# [1. 1. 1. 1. 0. 1.] is list of length 6, ['1', '1', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015973731071647974, fixed prior is 0.015625
# [1. 1. 1. 1. 1. 0.] is list of length 6, ['1', '1', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015944809773416703, fixed prior is 0.015625
# [1. 1. 1. 1. 1. 1.] is list of length 6, ['1', '1', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01598070890489167, fixed prior is 0.015625
# False 9999
# state in train.py's compute_action is None
# action is 2.5999999046325684
# [0. 0. 0. 0. 0. 0.] is list of length 6, ['0', '0', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014861130028897409, fixed prior is 0.015625
# [0. 0. 0. 0. 0. 1.] is list of length 6, ['0', '0', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015774130983667874, fixed prior is 0.015625
# [0. 0. 0. 0. 1. 0.] is list of length 6, ['0', '0', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014069363940650718, fixed prior is 0.015625
# [0. 0. 0. 0. 1. 1.] is list of length 6, ['0', '0', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015446941608241919, fixed prior is 0.015625
# [0. 0. 0. 1. 0. 0.] is list of length 6, ['0', '0', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016117298744385722, fixed prior is 0.015625
# [0. 0. 0. 1. 0. 1.] is list of length 6, ['0', '0', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015705239951285373, fixed prior is 0.015625
# [0. 0. 0. 1. 1. 0.] is list of length 6, ['0', '0', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014156247025052034, fixed prior is 0.015625
# [0. 0. 0. 1. 1. 1.] is list of length 6, ['0', '0', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016125703545183643, fixed prior is 0.015625
# [0. 0. 1. 0. 0. 0.] is list of length 6, ['0', '0', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01581465122422598, fixed prior is 0.015625
# [0. 0. 1. 0. 0. 1.] is list of length 6, ['0', '0', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015822532090749214, fixed prior is 0.015625
# [0. 0. 1. 0. 1. 0.] is list of length 6, ['0', '0', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016013661601129745, fixed prior is 0.015625
# [0. 0. 1. 0. 1. 1.] is list of length 6, ['0', '0', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01568788891373502, fixed prior is 0.015625
# [0. 0. 1. 1. 0. 0.] is list of length 6, ['0', '0', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01595309975158651, fixed prior is 0.015625
# [0. 0. 1. 1. 0. 1.] is list of length 6, ['0', '0', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016125703545183643, fixed prior is 0.015625
# [0. 0. 1. 1. 1. 0.] is list of length 6, ['0', '0', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015832978615491787, fixed prior is 0.015625
# [0. 0. 1. 1. 1. 1.] is list of length 6, ['0', '0', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016125703545183643, fixed prior is 0.015625
# [0. 1. 0. 0. 0. 0.] is list of length 6, ['0', '1', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015680648013919437, fixed prior is 0.015625
# [0. 1. 0. 0. 0. 1.] is list of length 6, ['0', '1', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016125703545183643, fixed prior is 0.015625
# [0. 1. 0. 0. 1. 0.] is list of length 6, ['0', '1', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01550902583125682, fixed prior is 0.015625
# [0. 1. 0. 0. 1. 1.] is list of length 6, ['0', '1', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015939527028268445, fixed prior is 0.015625
# [0. 1. 0. 1. 0. 0.] is list of length 6, ['0', '1', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016125324082341255, fixed prior is 0.015625
# [0. 1. 0. 1. 0. 1.] is list of length 6, ['0', '1', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014857343268755558, fixed prior is 0.015625
# [0. 1. 0. 1. 1. 0.] is list of length 6, ['0', '1', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016125703545183643, fixed prior is 0.015625
# [0. 1. 0. 1. 1. 1.] is list of length 6, ['0', '1', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016125703545183643, fixed prior is 0.015625
# [0. 1. 1. 0. 0. 0.] is list of length 6, ['0', '1', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014886480986200818, fixed prior is 0.015625
# [0. 1. 1. 0. 0. 1.] is list of length 6, ['0', '1', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01610917823955861, fixed prior is 0.015625
# [0. 1. 1. 0. 1. 0.] is list of length 6, ['0', '1', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015883620707467166, fixed prior is 0.015625
# [0. 1. 1. 0. 1. 1.] is list of length 6, ['0', '1', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016125522848592026, fixed prior is 0.015625
# [0. 1. 1. 1. 0. 0.] is list of length 6, ['0', '1', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015422933632987522, fixed prior is 0.015625
# [0. 1. 1. 1. 0. 1.] is list of length 6, ['0', '1', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016095750073513836, fixed prior is 0.015625
# [0. 1. 1. 1. 1. 0.] is list of length 6, ['0', '1', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015244129867733236, fixed prior is 0.015625
# [0. 1. 1. 1. 1. 1.] is list of length 6, ['0', '1', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015748227637324513, fixed prior is 0.015625
# [1. 0. 0. 0. 0. 0.] is list of length 6, ['1', '0', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01587119770900413, fixed prior is 0.015625
# [1. 0. 0. 0. 0. 1.] is list of length 6, ['1', '0', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015922733087043884, fixed prior is 0.015625
# [1. 0. 0. 0. 1. 0.] is list of length 6, ['1', '0', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01606602427954947, fixed prior is 0.015625
# [1. 0. 0. 0. 1. 1.] is list of length 6, ['1', '0', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014459425263421612, fixed prior is 0.015625
# [1. 0. 0. 1. 0. 0.] is list of length 6, ['1', '0', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016041559165688942, fixed prior is 0.015625
# [1. 0. 0. 1. 0. 1.] is list of length 6, ['1', '0', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01607064173936302, fixed prior is 0.015625
# [1. 0. 0. 1. 1. 0.] is list of length 6, ['1', '0', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01578006470986456, fixed prior is 0.015625
# [1. 0. 0. 1. 1. 1.] is list of length 6, ['1', '0', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015035364032523256, fixed prior is 0.015625
# [1. 0. 1. 0. 0. 0.] is list of length 6, ['1', '0', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016078418861090214, fixed prior is 0.015625
# [1. 0. 1. 0. 0. 1.] is list of length 6, ['1', '0', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016125703545183643, fixed prior is 0.015625
# [1. 0. 1. 0. 1. 0.] is list of length 6, ['1', '0', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016082633910250586, fixed prior is 0.015625
# [1. 0. 1. 0. 1. 1.] is list of length 6, ['1', '0', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015234209831184646, fixed prior is 0.015625
# [1. 0. 1. 1. 0. 0.] is list of length 6, ['1', '0', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.012464470225799325, fixed prior is 0.015625
# [1. 0. 1. 1. 0. 1.] is list of length 6, ['1', '0', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016118752749626243, fixed prior is 0.015625
# [1. 0. 1. 1. 1. 0.] is list of length 6, ['1', '0', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014146305135993166, fixed prior is 0.015625
# [1. 0. 1. 1. 1. 1.] is list of length 6, ['1', '0', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01597447148654277, fixed prior is 0.015625
# [1. 1. 0. 0. 0. 0.] is list of length 6, ['1', '1', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016125703545183643, fixed prior is 0.015625
# [1. 1. 0. 0. 0. 1.] is list of length 6, ['1', '1', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014105855265461915, fixed prior is 0.015625
# [1. 1. 0. 0. 1. 0.] is list of length 6, ['1', '1', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015967827728446952, fixed prior is 0.015625
# [1. 1. 0. 0. 1. 1.] is list of length 6, ['1', '1', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01516816459941283, fixed prior is 0.015625
# [1. 1. 0. 1. 0. 0.] is list of length 6, ['1', '1', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015768810697819127, fixed prior is 0.015625
# [1. 1. 0. 1. 0. 1.] is list of length 6, ['1', '1', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016125703545183643, fixed prior is 0.015625
# ...
# updated_prior is 0.012958250141362503, fixed prior is 0.015625
# [1. 0. 1. 1. 0. 1.] is list of length 6, ['1', '0', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015313717694946018, fixed prior is 0.015625
# [1. 0. 1. 1. 1. 0.] is list of length 6, ['1', '0', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.012502729061839007, fixed prior is 0.015625
# [1. 0. 1. 1. 1. 1.] is list of length 6, ['1', '0', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01536855329596383, fixed prior is 0.015625
# [1. 1. 0. 0. 0. 0.] is list of length 6, ['1', '1', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014025848201966137, fixed prior is 0.015625
# [1. 1. 0. 0. 0. 1.] is list of length 6, ['1', '1', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.013281997320787478, fixed prior is 0.015625
# [1. 1. 0. 0. 1. 0.] is list of length 6, ['1', '1', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016232716884795023, fixed prior is 0.015625
# [1. 1. 0. 0. 1. 1.] is list of length 6, ['1', '1', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016525188952191124, fixed prior is 0.015625
# [1. 1. 0. 1. 0. 0.] is list of length 6, ['1', '1', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.0168621327777256, fixed prior is 0.015625
# [1. 1. 0. 1. 0. 1.] is list of length 6, ['1', '1', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.017014880797645612, fixed prior is 0.015625
# [1. 1. 0. 1. 1. 0.] is list of length 6, ['1', '1', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.017456874656851865, fixed prior is 0.015625
# [1. 1. 0. 1. 1. 1.] is list of length 6, ['1', '1', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016208601705533104, fixed prior is 0.015625
# [1. 1. 1. 0. 0. 0.] is list of length 6, ['1', '1', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014594279712167342, fixed prior is 0.015625
# [1. 1. 1. 0. 0. 1.] is list of length 6, ['1', '1', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016430056027904875, fixed prior is 0.015625
# [1. 1. 1. 0. 1. 0.] is list of length 6, ['1', '1', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016543149465554838, fixed prior is 0.015625
# [1. 1. 1. 0. 1. 1.] is list of length 6, ['1', '1', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015784158613980727, fixed prior is 0.015625
# [1. 1. 1. 1. 0. 0.] is list of length 6, ['1', '1', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01752313943378193, fixed prior is 0.015625
# [1. 1. 1. 1. 0. 1.] is list of length 6, ['1', '1', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016736517852361008, fixed prior is 0.015625
# [1. 1. 1. 1. 1. 0.] is list of length 6, ['1', '1', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014749117577256844, fixed prior is 0.015625
# [1. 1. 1. 1. 1. 1.] is list of length 6, ['1', '1', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.012845352928340508, fixed prior is 0.015625
# False 9999
# state in train.py's compute_action is None
# action is 2.3922910690307617
# [0. 0. 0. 0. 0. 0.] is list of length 6, ['0', '0', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016633779866281118, fixed prior is 0.015625
# [0. 0. 0. 0. 0. 1.] is list of length 6, ['0', '0', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016938218627152703, fixed prior is 0.015625
# [0. 0. 0. 0. 1. 0.] is list of length 6, ['0', '0', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.012492633512099822, fixed prior is 0.015625
# [0. 0. 0. 0. 1. 1.] is list of length 6, ['0', '0', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01645452739408999, fixed prior is 0.015625
# [0. 0. 0. 1. 0. 0.] is list of length 6, ['0', '0', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016699047937098224, fixed prior is 0.015625
# [0. 0. 0. 1. 0. 1.] is list of length 6, ['0', '0', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.0162070938533857, fixed prior is 0.015625
# [0. 0. 0. 1. 1. 0.] is list of length 6, ['0', '0', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015219997369462055, fixed prior is 0.015625
# [0. 0. 0. 1. 1. 1.] is list of length 6, ['0', '0', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015952751217644556, fixed prior is 0.015625
# [0. 0. 1. 0. 0. 0.] is list of length 6, ['0', '0', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.013558736999802236, fixed prior is 0.015625
# [0. 0. 1. 0. 0. 1.] is list of length 6, ['0', '0', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015978971811725383, fixed prior is 0.015625
# [0. 0. 1. 0. 1. 0.] is list of length 6, ['0', '0', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.013400524822565252, fixed prior is 0.015625
# [0. 0. 1. 0. 1. 1.] is list of length 6, ['0', '0', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01744103208164854, fixed prior is 0.015625
# [0. 0. 1. 1. 0. 0.] is list of length 6, ['0', '0', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.017797521712840197, fixed prior is 0.015625
# [0. 0. 1. 1. 0. 1.] is list of length 6, ['0', '0', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.017736581898487234, fixed prior is 0.015625
# [0. 0. 1. 1. 1. 0.] is list of length 6, ['0', '0', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01531926271460885, fixed prior is 0.015625
# [0. 0. 1. 1. 1. 1.] is list of length 6, ['0', '0', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016268097458232315, fixed prior is 0.015625
# [0. 1. 0. 0. 0. 0.] is list of length 6, ['0', '1', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014454809577004324, fixed prior is 0.015625
# [0. 1. 0. 0. 0. 1.] is list of length 6, ['0', '1', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015792650571354625, fixed prior is 0.015625
# [0. 1. 0. 0. 1. 0.] is list of length 6, ['0', '1', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016780751772386762, fixed prior is 0.015625
# [0. 1. 0. 0. 1. 1.] is list of length 6, ['0', '1', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.017461510244547822, fixed prior is 0.015625
# [0. 1. 0. 1. 0. 0.] is list of length 6, ['0', '1', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01561023360715547, fixed prior is 0.015625
# [0. 1. 0. 1. 0. 1.] is list of length 6, ['0', '1', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.013926158662694605, fixed prior is 0.015625
# [0. 1. 0. 1. 1. 0.] is list of length 6, ['0', '1', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016681743032190284, fixed prior is 0.015625
# [0. 1. 0. 1. 1. 1.] is list of length 6, ['0', '1', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01819841041482164, fixed prior is 0.015625
# [0. 1. 1. 0. 0. 0.] is list of length 6, ['0', '1', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01469737316245311, fixed prior is 0.015625
# [0. 1. 1. 0. 0. 1.] is list of length 6, ['0', '1', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01651642164557228, fixed prior is 0.015625
# [0. 1. 1. 0. 1. 0.] is list of length 6, ['0', '1', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016510325751103856, fixed prior is 0.015625
# [0. 1. 1. 0. 1. 1.] is list of length 6, ['0', '1', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.012124164108136982, fixed prior is 0.015625
# [0. 1. 1. 1. 0. 0.] is list of length 6, ['0', '1', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014476544512528647, fixed prior is 0.015625
# [0. 1. 1. 1. 0. 1.] is list of length 6, ['0', '1', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014513137116040133, fixed prior is 0.015625
# [0. 1. 1. 1. 1. 0.] is list of length 6, ['0', '1', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01493822841741668, fixed prior is 0.015625
# [0. 1. 1. 1. 1. 1.] is list of length 6, ['0', '1', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.013452172051664121, fixed prior is 0.015625
# [1. 0. 0. 0. 0. 0.] is list of length 6, ['1', '0', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.018274758593892774, fixed prior is 0.015625
# [1. 0. 0. 0. 0. 1.] is list of length 6, ['1', '0', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016578735068724818, fixed prior is 0.015625
# [1. 0. 0. 0. 1. 0.] is list of length 6, ['1', '0', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015992893121043912, fixed prior is 0.015625
# [1. 0. 0. 0. 1. 1.] is list of length 6, ['1', '0', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015974786039774095, fixed prior is 0.015625
# [1. 0. 0. 1. 0. 0.] is list of length 6, ['1', '0', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01377969627730479, fixed prior is 0.015625
# [1. 0. 0. 1. 0. 1.] is list of length 6, ['1', '0', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014983138234281478, fixed prior is 0.015625
# [1. 0. 0. 1. 1. 0.] is list of length 6, ['1', '0', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015248187849117219, fixed prior is 0.015625
# [1. 0. 0. 1. 1. 1.] is list of length 6, ['1', '0', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015742940304618532, fixed prior is 0.015625
# [1. 0. 1. 0. 0. 0.] is list of length 6, ['1', '0', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01618772127130204, fixed prior is 0.015625
# [1. 0. 1. 0. 0. 1.] is list of length 6, ['1', '0', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015189938930335016, fixed prior is 0.015625
# [1. 0. 1. 0. 1. 0.] is list of length 6, ['1', '0', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01756021820387926, fixed prior is 0.015625
# [1. 0. 1. 0. 1. 1.] is list of length 6, ['1', '0', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.0156519911636821, fixed prior is 0.015625
# [1. 0. 1. 1. 0. 0.] is list of length 6, ['1', '0', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01303234141098408, fixed prior is 0.015625
# [1. 0. 1. 1. 0. 1.] is list of length 6, ['1', '0', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01540127680009273, fixed prior is 0.015625
# [1. 0. 1. 1. 1. 0.] is list of length 6, ['1', '0', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.012574215802704531, fixed prior is 0.015625
# [1. 0. 1. 1. 1. 1.] is list of length 6, ['1', '0', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.015366878466290222, fixed prior is 0.015625
# [1. 1. 0. 0. 0. 0.] is list of length 6, ['1', '1', '0', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014100246886283167, fixed prior is 0.015625
# [1. 1. 0. 0. 0. 1.] is list of length 6, ['1', '1', '0', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.013357939676728452, fixed prior is 0.015625
# [1. 1. 0. 0. 1. 0.] is list of length 6, ['1', '1', '0', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01632553054329688, fixed prior is 0.015625
# [1. 1. 0. 0. 1. 1.] is list of length 6, ['1', '1', '0', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01620682383252844, fixed prior is 0.015625
# [1. 1. 0. 1. 0. 0.] is list of length 6, ['1', '1', '0', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01695854524178519, fixed prior is 0.015625
# [1. 1. 0. 1. 0. 1.] is list of length 6, ['1', '1', '0', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01710634892039114, fixed prior is 0.015625
# [1. 1. 0. 1. 1. 0.] is list of length 6, ['1', '1', '0', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.0175566876711741, fixed prior is 0.015625
# [1. 1. 0. 1. 1. 1.] is list of length 6, ['1', '1', '0', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016301277480892627, fixed prior is 0.015625
# [1. 1. 1. 0. 0. 0.] is list of length 6, ['1', '1', '1', '0', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014677725293267479, fixed prior is 0.015625
# [1. 1. 1. 0. 0. 1.] is list of length 6, ['1', '1', '1', '0', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.016523998010640292, fixed prior is 0.015625
# [1. 1. 1. 0. 1. 0.] is list of length 6, ['1', '1', '1', '0', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01663773808161574, fixed prior is 0.015625
# [1. 1. 1. 0. 1. 1.] is list of length 6, ['1', '1', '1', '0', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01587440755491491, fixed prior is 0.015625
# [1. 1. 1. 1. 0. 0.] is list of length 6, ['1', '1', '1', '1', '0', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.017102514011014935, fixed prior is 0.015625
# [1. 1. 1. 1. 0. 1.] is list of length 6, ['1', '1', '1', '1', '0', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.0164436622515411, fixed prior is 0.015625
# [1. 1. 1. 1. 1. 0.] is list of length 6, ['1', '1', '1', '1', '1', '0'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.014735690062398556, fixed prior is 0.015625
# [1. 1. 1. 1. 1. 1.] is list of length 6, ['1', '1', '1', '1', '1', '1'] has length 6
# state in train.py's compute_action is None
# updated_prior is 0.01231773301930405, fixed prior is 0.015625
# False 9999

# %%
ray.rllib.agents.trainer_template.MADDPG
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-6f1a48bfb6b2> in <module>
# ----> 1 ray.rllib.agents.trainer_template.MADDPG
#
# AttributeError: module 'ray.rllib.agents.trainer_template' has no attribute 'MADDPG'

# %%
pr_ped_given_action(.6538469, 0.14252673, 2.4491935, 0.14200129, 2.5765653, 0.5100277175584501, False)

# %%
b = np.array([11,22, 3, 4, 5, 6, 7])
c = [1, 2, 3]
b[c]

# %%
for idx, val in enumerate(b, 1):
    print(idx, val)

# %%
def f(a, b):
    return a + b

# %%
f(1, 2, cat=40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-7037f43aa012> in <module>
# ----> 1 f(1, 2, cat=40)
#
# TypeError: f() got an unexpected keyword argument 'cat'

# %%
fig = plt.figure()
# Out:
# [1, 2, 3]

# %%
fig = plt.figure(figsize=(15, 15))

x1 = np.linspace(0.0, 1.0)
x2 = np.linspace(0.0, 1.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

vax = plt.subplot(2, 2, 1)
plt.plot(x1, y1, 'o-')
vax.set_title('A tale of 2 subplots')
vax.set_ylabel('Damped oscillation')

hax = plt.subplot(2, 2, 3)
hax.plot(x2, y2, '.-')
hax.set_title('A tale of 2 subplots')

hax.set_xlabel('time (s)')
hax.set_ylabel('Undamped')
# Out:
# Text(0, 0.5, 'Undamped')
